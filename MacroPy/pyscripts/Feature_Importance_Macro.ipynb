# %%
import os
import pandas as pd
import numpy as np
import h2o
from h2o.estimators.gbm import H2OGradientBoostingEstimator
from h2o.estimators.random_forest import H2ORandomForestEstimator
import time
import itertools
import statsmodels.api as sm
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
import lightgbm as lgb
from sklearn.model_selection import cross_val_score
from functools import partial

# %%
data = pd.read_csv("/home/puneetj/CLA_Macro/MacroPy/data/german_data.csv")
del data["Unnamed: 0"]
data.head()
#data["am"].unique()
# Out:
#      ca_status  duration credit_history              purpose  credit_amount  \
# 0       (;0DM)         6       critical     radio/television           1169
# 1  <0DM;200DM)        48       all paid     radio/television           5951
# 2      No Acc.        12       critical            education           2096
# 3       (;0DM)        42       all paid  furniture/equipment           7882
# 4       (;0DM)        24          delay            car (new)           4870
#
#                         savings present_employment_since  \
# 0  unknown / no savings account                     <7;)
# 1                      (;100DM)                    <1;4)
# 2                      (;100DM)                    <4;7)
# 3                      (;100DM)                    <4;7)
# 4                      (;100DM)                    <1;4)
#
#    installment_rate_income              status_sex other_debtors ...  age  \
# 0                        4             male:single          none ...   67
# 1                        2  female:div./sep./marr.          none ...   22
# 2                        2             male:single          none ...   49
# 3                        2             male:single     guarantor ...   45
# 4                        3             male:single          none ...   53
#
#   other_installment   housing existing_credits           job  \
# 0              none       own                2  skilled/off.
# 1              none       own                1  skilled/off.
# 2              none       own                1    unsk. res.
# 3              none  for free                1  skilled/off.
# 4              none  for free                2  skilled/off.
#
#    liable_maintenance_people telephone  foreign_worker    gb tar
# 0                          1       yes             yes  good   1
# 1                          1      none             yes   bad   0
# 2                          2      none             yes  good   1
# 3                          2      none             yes  good   1
# 4                          2      none             yes   bad   0
#
# [5 rows x 22 columns]

# %%
class Logger(object):
    def __init__(self):
        pass

    def info(self, msg):
        print 'INFO: {0}'.format(msg)


class VariableSelector():
    #Currently only support's H2o and LightGBM for generating Feature Importance
    #either input the pandas dataframe using dataset or specify CSV location
    #the Specify addtional categories  are the columns which need to be treated as Category
    def __init__(self, Algorithm = "LightGBM",dataset = "", Input_Dir = "", Target ="",
                 Exclude_columns = "", Num_features = 20, preprocess = True,log = None,
                 spcfy_cat = []):
        self.Algorithm = Algorithm
        self.dataset = dataset
        self.data = self.load_data(dataset,Input_Dir)
        self.Input_Dir = Input_Dir
        self.log = self.setup_log(log)
        self.log.info('Run initiated.')
        self.Target =Target
        self.Exclude_columns = Exclude_columns
        self.spcfy_cat = spcfy_cat
        self.cols_to_use = self.get_cols_to_use(self.data,Target,Exclude_columns)
        self.Cat_columns = self.get_Cat_columns(self.data,Target,spcfy_cat,self.cols_to_use)
        self.variable_importance  = self.get_variable_importance(Algorithm,self.data,Target,Input_Dir,
                                                                 Exclude_columns,preprocess,self.cols_to_use,
                                                                 spcfy_cat,self.Cat_columns)
        
    def get_cols_to_use(self,data,Target,Exclude_columns):
        if isinstance(Exclude_columns, str):
            Exclude_columns = list(Exclude_columns)  
        return list(set(data.columns)-set([Target])- set(Exclude_columns))
    
    def get_Cat_columns(self,data,Target,spcfy_cat,cols_to_use):
        return list(set(data[cols_to_use].select_dtypes(include=['object']).columns)
                                         .union(set(spcfy_cat)))
    
    
    def get_variable_importance(self,Algorithm,dataset,Target,Input_Dir,
                                Exclude_columns,preprocess,cols_to_use,
                                spcfy_cat,Cat_columns):
        data = self.load_data(dataset,Input_Dir)
        self.log.info('Dataset Loaded')   
        data = self.preprocess_data(preprocess,self.Algorithm,data,spcfy_cat,self.Cat_columns) 
        self.data = data
        return self.build_model(data,Algorithm,Target,cols_to_use,Cat_columns)

        
    def build_model(self,data,Algorithm,Target,cols_to_use,Cat_columns):
        if Algorithm in ["H2o"]:
            model = H2ORandomForestEstimator(model_id="Random_forest_FI",
                                            ntrees=400,
                                            stopping_rounds=2,
                                            score_each_iteration=True,
                                            seed=1000000)
            model.train(cols_to_use,y= Target, training_frame=data)
            self.log.info('Model Build')  
            return model._model_json['output']['variable_importances'].as_data_frame()
        else:
            train_data = lgb.Dataset( data[cols_to_use],data[Target] ,feature_name = cols_to_use,
                                     categorical_feature=Cat_columns)
            train_data.set_categorical_feature(Cat_columns)
            self.log.info(train_data) 
            params = {
                            'task': 'train',
                            'boosting_type': 'gbdt',
                            'objective': 'regression',
                            #'metric': {'l2', 'auc'},
                            #'num_leaves': 31,
                            'learning_rate': 0.1,
                            'feature_fraction': 0.9,
                            'bagging_fraction': 0.8,
                            'bagging_freq': 5,
                            'verbose': 0,
                           # 'categorical_feature' : ['name:' + str(col) for col in Cat_columns]
                        }
            if len(data[Target].unique()) == 2:
                params["objective"] = 'binary'
            elif len(data[Target].unique()) < 10 :
                params["objective"] = 'multiclass'
            model = lgb.train(params,
                            train_data,
                            num_boost_round=200,
                           # valid_sets=lgb_eval,
                           # early_stopping_rounds=25
                             )
            self.log.info(params) 
            self.log.info('Model Build')  
            importances = model.feature_importance()
            #print (importances.shape)
            imp_list = []
            for row in zip(data[cols_to_use].columns, map(lambda x:round(x,4), importances)):
                imp_list.append(row)
            return (pd.DataFrame(imp_list, columns=['Column', 'Importance'])).sort_values(['Importance'], ascending = False)

        
        
        
    def setup_log(self, log):
        if log is None:
            log = Logger()
        return log
    
    def load_data(self,data,Input_Dir):
        if isinstance(data, pd.DataFrame):
            return data
        else:
            return pd.read_csv(Input_Dir)
    
    
        
    def preprocess_data(self,preprocess,Algorithm,data,spcfy_cat,Cat_columns):
        if preprocess == False:
            self.log.info("No Preprocessing Done")
        elif  Algorithm in ["H2o"]:
            h2o.init()
            h2o.remove_all() 
            self.log.info('Preprocessed Data h2o frame') 
            data = h2o.H2OFrame(data)
            for col in spcfy_cat:
                data[col] = data[col].asfactor()

            return data
              
        else:
            for c in Cat_columns:
                lbl = LabelEncoder()
                lbl.fit(list(data[c].values) )
                data[c] = lbl.transform(list(data[c].values))
                self.log.info('Preprocessed Data pd frame')
            return data

# %%
#data.dtypes
m = VariableSelector(Input_Dir = "/home/puneetj/CLA_Macro/MacroPy/data/german_data.csv",
                     Algorithm = "LightGBM",
                    # dataset = data,
                     Target ="tar",
                     preprocess = True,
                 #    Exclude_columns = ["status_sex"],
                  #  spcfy_cat = ["installment_rate_income"]
                    )
m.variable_importance
#h2o.init()
#h2o.shutdown(prompt=False)
# Out:
# INFO: Run initiated.
# INFO: Dataset Loaded
# INFO: Preprocessed Data pd frame
# INFO: Preprocessed Data pd frame
# INFO: Preprocessed Data pd frame
# INFO: Preprocessed Data pd frame
# INFO: Preprocessed Data pd frame
# INFO: Preprocessed Data pd frame
# INFO: Preprocessed Data pd frame
# INFO: Preprocessed Data pd frame
# INFO: Preprocessed Data pd frame
# INFO: Preprocessed Data pd frame
# INFO: Preprocessed Data pd frame
# INFO: Preprocessed Data pd frame
# INFO: Preprocessed Data pd frame
# INFO: Preprocessed Data pd frame
# INFO: <lightgbm.basic.Dataset object at 0x7f1fb5119350>
# INFO: {'categorical_column': [], 'task': 'train', 'verbose': 0, 'max_bin': 255, 'objective': 'binary', 'bagging_freq': 5, 'learning_rate': 0.1, 'feature_fraction': 0.9, 'bagging_fraction': 0.8, 'boosting_type': 'gbdt'}
# INFO: Model Build
#                        Column  Importance
# 4                    duration       406.0
# 17                        age       303.0
# 8                  Unnamed: 0       294.0
# 19                  ca_status       275.0
# 14                    purpose       270.0
# 18              credit_amount       267.0
# 11             credit_history       225.0
# 12   present_employment_since       123.0
# 3                          gb       119.0
# 21                   property       105.0
# 20                    savings        99.0
# 5           other_installment        77.0
# 2     present_residence_since        73.0
# 10                 status_sex        68.0
# 15    installment_rate_income        67.0
# 1                   telephone        32.0
# 6            existing_credits        27.0
# 13                        job        26.0
# 9                     housing        20.0
# 7               other_debtors         2.0
# 0   liable_maintenance_people         2.0
# 16             foreign_worker         0.0

# %%
param = {"model_id":"Random_forest_FI",
         "ntrees":400,
         "stopping_rounds":2,
         "score_each_iteration":True,
         "seed"1000000}

# %%
spcfy_cat
# Out:
#      Unnamed: 0    ca_status  duration credit_history              purpose  \
# 0             1       (;0DM)         6       critical     radio/television
# 1             2  <0DM;200DM)        48       all paid     radio/television
# 2             3      No Acc.        12       critical            education
# 3             4       (;0DM)        42       all paid  furniture/equipment
# 4             5       (;0DM)        24          delay            car (new)
# 5             6      No Acc.        36       all paid            education
# 6             7      No Acc.        24       all paid  furniture/equipment
# 7             8  <0DM;200DM)        36       all paid           car (used)
# 8             9      No Acc.        12       all paid     radio/television
# 9            10  <0DM;200DM)        30       critical            car (new)
# 10           11  <0DM;200DM)        12       all paid            car (new)
# 11           12       (;0DM)        48       all paid             business
# 12           13  <0DM;200DM)        12       all paid     radio/television
# 13           14       (;0DM)        24       critical            car (new)
# 14           15       (;0DM)        15       all paid            car (new)
# 15           16       (;0DM)        24       all paid     radio/television
# 16           17      No Acc.        24       critical     radio/television
# 17           18       (;0DM)        30     no credits             business
# 18           19  <0DM;200DM)        24       all paid           car (used)
# 19           20      No Acc.        24       all paid     radio/television
# 20           21      No Acc.         9       critical            car (new)
# 21           22       (;0DM)         6       all paid     radio/television
# 22           23       (;0DM)        10       critical            car (new)
# 23           24  <0DM;200DM)        12       critical           car (used)
# 24           25      No Acc.        10       critical  furniture/equipment
# 25           26       (;0DM)         6       all paid  furniture/equipment
# 26           27      No Acc.         6     no credits     radio/television
# 27           28     <200DM;)        12       paid off     radio/television
# 28           29  <0DM;200DM)         7       all paid     radio/television
# 29           30       (;0DM)        60          delay             business
# ..          ...          ...       ...            ...                  ...
# 970         971  <0DM;200DM)        15       all paid              repairs
# 971         972      No Acc.        24       all paid            car (new)
# 972         973       (;0DM)        24       paid off            car (new)
# 973         974       (;0DM)        60       all paid             business
# 974         975      No Acc.        30       critical     radio/television
# 975         976     <200DM;)        24       all paid     radio/television
# 976         977  <0DM;200DM)         6       all paid     radio/television
# 977         978  <0DM;200DM)        18          delay             business
# 978         979      No Acc.        24          delay            car (new)
# 979         980  <0DM;200DM)        15       paid off            car (new)
# 980         981  <0DM;200DM)        30       critical  furniture/equipment
# 981         982      No Acc.        48       all paid             business
# 982         983     <200DM;)        21       all paid            car (new)
# 983         984       (;0DM)        36       all paid           car (used)
# 984         985      No Acc.        24       critical  furniture/equipment
# 985         986       (;0DM)        15       critical  furniture/equipment
# 986         987     <200DM;)        42     no credits             business
# 987         988      No Acc.        13       all paid     radio/television
# 988         989       (;0DM)        24       all paid           car (used)
# 989         990  <0DM;200DM)        24       critical     radio/television
# 990         991      No Acc.        12       critical            education
# 991         992      No Acc.        15       paid off     radio/television
# 992         993       (;0DM)        18       all paid     radio/television
# 993         994       (;0DM)        36       all paid  furniture/equipment
# 994         995      No Acc.        12       all paid            car (new)
# 995         996      No Acc.        12       all paid  furniture/equipment
# 996         997       (;0DM)        30       all paid           car (used)
# 997         998      No Acc.        12       all paid     radio/television
# 998         999       (;0DM)        45       all paid     radio/television
# 999        1000  <0DM;200DM)        45       critical           car (used)
#
#      credit_amount                       savings present_employment_since  \
# 0             1169  unknown / no savings account                     <7;)
# 1             5951                      (;100DM)                    <1;4)
# 2             2096                      (;100DM)                    <4;7)
# 3             7882                      (;100DM)                    <4;7)
# 4             4870                      (;100DM)                    <1;4)
# 5             9055  unknown / no savings account                    <1;4)
# 6             2835                    <500;1000)                     <7;)
# 7             6948                      (;100DM)                    <1;4)
# 8             3059                       <1000;)                    <4;7)
# 9             5234                      (;100DM)               unemployed
# 10            1295                      (;100DM)                     (;1)
# 11            4308                      (;100DM)                     (;1)
# 12            1567                      (;100DM)                    <1;4)
# 13            1199                      (;100DM)                     <7;)
# 14            1403                      (;100DM)                    <1;4)
# 15            1282                     <100;500)                    <1;4)
# 16            2424  unknown / no savings account                     <7;)
# 17            8072  unknown / no savings account                     (;1)
# 18           12579                      (;100DM)                     <7;)
# 19            3430                    <500;1000)                     <7;)
# 20            2134                      (;100DM)                    <1;4)
# 21            2647                    <500;1000)                    <1;4)
# 22            2241                      (;100DM)                     (;1)
# 23            1804                     <100;500)                     (;1)
# 24            2069  unknown / no savings account                    <1;4)
# 25            1374                      (;100DM)                    <1;4)
# 26             426                      (;100DM)                     <7;)
# 27             409                       <1000;)                    <1;4)
# 28            2415                      (;100DM)                    <1;4)
# 29            6836                      (;100DM)                     <7;)
# ..             ...                           ...                      ...
# 970           1514                     <100;500)                    <1;4)
# 971           7393                      (;100DM)                    <1;4)
# 972           1193                      (;100DM)               unemployed
# 973           7297                      (;100DM)                     <7;)
# 974           2831                      (;100DM)                    <1;4)
# 975           1258                    <500;1000)                    <1;4)
# 976            753                      (;100DM)                    <1;4)
# 977           2427  unknown / no savings account                     <7;)
# 978           2538                      (;100DM)                     <7;)
# 979           1264                     <100;500)                    <1;4)
# 980           8386                      (;100DM)                    <4;7)
# 981           4844                      (;100DM)               unemployed
# 982           2923                     <100;500)                    <1;4)
# 983           8229                      (;100DM)                    <1;4)
# 984           2028                      (;100DM)                    <4;7)
# 985           1433                      (;100DM)                    <1;4)
# 986           6289                      (;100DM)                     (;1)
# 987           1409                     <100;500)               unemployed
# 988           6579                      (;100DM)               unemployed
# 989           1743                      (;100DM)                     <7;)
# 990           3565  unknown / no savings account                     (;1)
# 991           1569                     <100;500)                     <7;)
# 992           1936  unknown / no savings account                    <4;7)
# 993           3959                      (;100DM)               unemployed
# 994           2390  unknown / no savings account                     <7;)
# 995           1736                      (;100DM)                    <4;7)
# 996           3857                      (;100DM)                    <1;4)
# 997            804                      (;100DM)                     <7;)
# 998           1845                      (;100DM)                    <1;4)
# 999           4576                     <100;500)               unemployed
#
#      installment_rate_income              status_sex ... age  \
# 0                          4             male:single ...  67
# 1                          2  female:div./sep./marr. ...  22
# 2                          2             male:single ...  49
# 3                          2             male:single ...  45
# 4                          3             male:single ...  53
# 5                          2             male:single ...  35
# 6                          3             male:single ...  53
# 7                          2             male:single ...  35
# 8                          2          male:div./sep. ...  61
# 9                          4          male:marr/wid. ...  28
# 10                         3  female:div./sep./marr. ...  25
# 11                         3  female:div./sep./marr. ...  24
# 12                         1  female:div./sep./marr. ...  22
# 13                         4             male:single ...  60
# 14                         2  female:div./sep./marr. ...  28
# 15                         4  female:div./sep./marr. ...  32
# 16                         4             male:single ...  53
# 17                         2             male:single ...  25
# 18                         4  female:div./sep./marr. ...  44
# 19                         3             male:single ...  31
# 20                         4             male:single ...  48
# 21                         2             male:single ...  44
# 22                         1             male:single ...  48
# 23                         3             male:single ...  44
# 24                         2          male:marr/wid. ...  26
# 25                         1             male:single ...  36
# 26                         4          male:marr/wid. ...  39
# 27                         3  female:div./sep./marr. ...  42
# 28                         3             male:single ...  34
# 29                         3             male:single ...  63
# ..                       ...                     ... ...  ..
# 970                        4             male:single ...  22
# 971                        1             male:single ...  43
# 972                        1  female:div./sep./marr. ...  29
# 973                        4             male:single ...  36
# 974                        4  female:div./sep./marr. ...  33
# 975                        3  female:div./sep./marr. ...  57
# 976                        2  female:div./sep./marr. ...  64
# 977                        4             male:single ...  42
# 978                        4             male:single ...  47
# 979                        2          male:marr/wid. ...  25
# 980                        2             male:single ...  49
# 981                        3             male:single ...  33
# 982                        1  female:div./sep./marr. ...  28
# 983                        2             male:single ...  26
# 984                        2             male:single ...  30
# 985                        4  female:div./sep./marr. ...  25
# 986                        2          male:div./sep. ...  33
# 987                        2  female:div./sep./marr. ...  64
# 988                        4             male:single ...  29
# 989                        4             male:single ...  48
# 990                        2             male:single ...  37
# 991                        4             male:single ...  34
# 992                        2          male:marr/wid. ...  23
# 993                        4             male:single ...  30
# 994                        4             male:single ...  50
# 995                        3  female:div./sep./marr. ...  31
# 996                        4          male:div./sep. ...  40
# 997                        4             male:single ...  38
# 998                        4             male:single ...  23
# 999                        3             male:single ...  27
#
#      other_installment   housing  existing_credits                      job  \
# 0                 none       own                 2             skilled/off.
# 1                 none       own                 1             skilled/off.
# 2                 none       own                 1               unsk. res.
# 3                 none  for free                 1             skilled/off.
# 4                 none  for free                 2             skilled/off.
# 5                 none  for free                 1               unsk. res.
# 6                 none       own                 1             skilled/off.
# 7                 none      rent                 1  mng/self emp, hig qual.
# 8                 none       own                 1               unsk. res.
# 9                 none       own                 2  mng/self emp, hig qual.
# 10                none      rent                 1             skilled/off.
# 11                none      rent                 1             skilled/off.
# 12                none       own                 1             skilled/off.
# 13                none       own                 2               unsk. res.
# 14                none      rent                 1             skilled/off.
# 15                none       own                 1               unsk. res.
# 16                none       own                 2             skilled/off.
# 17                bank       own                 3             skilled/off.
# 18                none  for free                 1  mng/self emp, hig qual.
# 19                none       own                 1             skilled/off.
# 20                none       own                 3             skilled/off.
# 21                none      rent                 1             skilled/off.
# 22                none      rent                 2               unsk. res.
# 23                none       own                 1             skilled/off.
# 24                none       own                 2             skilled/off.
# 25                bank       own                 1               unsk. res.
# 26                none       own                 1               unsk. res.
# 27                none      rent                 2             skilled/off.
# 28                none       own                 1             skilled/off.
# 29                none       own                 2             skilled/off.
# ..                 ...       ...               ...                      ...
# 970               none       own                 1             skilled/off.
# 971               none       own                 1               unsk. res.
# 972               none      rent                 2       unemp./unsk. nonr.
# 973               none      rent                 1             skilled/off.
# 974               none       own                 1             skilled/off.
# 975               none       own                 1               unsk. res.
# 976               none       own                 1             skilled/off.
# 977               none       own                 2             skilled/off.
# 978               none       own                 2               unsk. res.
# 979               none      rent                 1             skilled/off.
# 980               none       own                 1             skilled/off.
# 981               bank      rent                 1  mng/self emp, hig qual.
# 982               bank       own                 1  mng/self emp, hig qual.
# 983               none       own                 1             skilled/off.
# 984               none       own                 2               unsk. res.
# 985               none      rent                 2             skilled/off.
# 986               none       own                 2             skilled/off.
# 987               none       own                 1             skilled/off.
# 988               none  for free                 1  mng/self emp, hig qual.
# 989               none       own                 2               unsk. res.
# 990               none       own                 2               unsk. res.
# 991               bank       own                 1               unsk. res.
# 992               none      rent                 2               unsk. res.
# 993               none       own                 1  mng/self emp, hig qual.
# 994               none       own                 1             skilled/off.
# 995               none       own                 1               unsk. res.
# 996               none       own                 1  mng/self emp, hig qual.
# 997               none       own                 1             skilled/off.
# 998               none  for free                 1             skilled/off.
# 999               none       own                 1             skilled/off.
#
#     liable_maintenance_people  telephone foreign_worker    gb tar
# 0                           1        yes            yes  good   1
# 1                           1       none            yes   bad   0
# 2                           2       none            yes  good   1
# 3                           2       none            yes  good   1
# 4                           2       none            yes   bad   0
# 5                           2        yes            yes  good   1
# 6                           1       none            yes  good   1
# 7                           1        yes            yes  good   1
# 8                           1       none            yes  good   1
# 9                           1       none            yes   bad   0
# 10                          1       none            yes   bad   0
# 11                          1       none            yes   bad   0
# 12                          1        yes            yes  good   1
# 13                          1       none            yes   bad   0
# 14                          1       none            yes  good   1
# 15                          1       none            yes   bad   0
# 16                          1       none            yes  good   1
# 17                          1       none            yes  good   1
# 18                          1        yes            yes   bad   0
# 19                          2        yes            yes  good   1
# 20                          1        yes            yes  good   1
# 21                          2       none            yes  good   1
# 22                          2       none             no  good   1
# 23                          1       none            yes  good   1
# 24                          1       none             no  good   1
# 25                          1        yes            yes  good   1
# 26                          1       none            yes  good   1
# 27                          1       none            yes  good   1
# 28                          1       none            yes  good   1
# 29                          1        yes            yes   bad   0
# ..                        ...        ...            ...   ...  ..
# 970                         1       none            yes  good   1
# 971                         2       none            yes  good   1
# 972                         1       none            yes   bad   0
# 973                         1       none            yes   bad   0
# 974                         1        yes            yes  good   1
# 975                         1       none            yes  good   1
# 976                         1       none            yes  good   1
# 977                         1       none            yes  good   1
# 978                         2       none            yes   bad   0
# 979                         1       none            yes   bad   0
# 980                         1       none            yes   bad   0
# 981                         1        yes            yes   bad   0
# 982                         1        yes            yes  good   1
# 983                         2       none            yes   bad   0
# 984                         1       none            yes  good   1
# 985                         1       none            yes  good   1
# 986                         1       none            yes  good   1
# 987                         1       none            yes  good   1
# 988                         1        yes            yes  good   1
# 989                         1       none            yes  good   1
# 990                         2       none            yes  good   1
# 991                         2       none            yes  good   1
# 992                         1       none            yes  good   1
# 993                         1        yes            yes  good   1
# 994                         1        yes            yes  good   1
# 995                         1       none            yes  good   1
# 996                         1        yes            yes  good   1
# 997                         1       none            yes  good   1
# 998                         1        yes            yes   bad   0
# 999                         1       none            yes  good   1
#
# [1000 rows x 23 columns]

# %%
for c in list(data.select_dtypes(include=['object']).columns):
    if c != 'ID':
        lbl = LabelEncoder()
        lbl.fit(list(data[c].values) )
        data[c] = lbl.transform(list(data[c].values))

# %%
cols_to_use =list(set(data.columns)- set(["tar"]))
start = time.time()
model_chk_r2.fit(data[cols_to_use], data.tar)
print ('Time taken: ', time.time() - start)
# Out:
# ('Time taken: ', 4.455770969390869)

# %%
model_chk_r2.feature_importances_
# Out:
# array([ 0.00469475,  0.00420092,  0.00872196,  0.05263122,  0.01032276,
#         0.01173249,  0.00640955,  0.0338489 ,  0.00279182,  0.0039686 ,
#         0.01499422,  0.0068513 ,  0.00113663,  0.00758774,  0.72868679,
#         0.02868227,  0.00734507,  0.00752421,  0.02093757,  0.0232123 ,
#         0.01371892])

# %%
# model_gbm1.feature_importances_
importances = model_chk_r2.feature_importances_
print (importances.shape)
imp_list = []
for row in zip(data[cols_to_use].columns, map(lambda x:round(x,4), importances)):
#     print (type(row))
    imp_list.append(row)

print (len(imp_list))

imp_df = pd.DataFrame(imp_list, columns=['Column', 'Importance'])
#imp_df.to_csv("/home/puneetj/CLA_Macro/MacroPy/data/feature_importance.csv", index=False)
imp_df.sort_values(["Importance"],ascending = False)
# Out:
# (21,)
# 21
#                        Column  Importance
# 14                         gb      0.7287
# 3                   ca_status      0.0526
# 7               credit_amount      0.0338
# 15                   duration      0.0287
# 19                        age      0.0232
# 18             credit_history      0.0209
# 10                    savings      0.0150
# 20                    purpose      0.0137
# 5    present_employment_since      0.0117
# 4                    property      0.0103
# 2     installment_rate_income      0.0087
# 13    present_residence_since      0.0076
# 17          other_installment      0.0075
# 16                 status_sex      0.0073
# 11                        job      0.0069
# 6                     housing      0.0064
# 0            existing_credits      0.0047
# 1               other_debtors      0.0042
# 9                   telephone      0.0040
# 8   liable_maintenance_people      0.0028
# 12             foreign_worker      0.0011

# %%
             #specify max number of bytes. uses all cores by default.
#h2o.remove_all()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321. connected.
# Warning: Your H2O cluster version is too old (3 months and 12 days)! Please download and install the latest version from http://h2o.ai/download/
# --------------------------  ---------------------------------
# H2O cluster uptime:         72 days 11 hours 27 mins
# H2O cluster version:        3.10.4.6
# H2O cluster version age:    3 months and 12 days !!!
# H2O cluster name:           H2O_started_from_R_govindm_pgr082
# H2O cluster total nodes:    1
# H2O cluster free memory:    25.67 Gb
# H2O cluster total cores:    24
# H2O cluster allowed cores:  24
# H2O cluster status:         locked, healthy
# H2O connection url:         http://localhost:54321
# H2O connection proxy:
# H2O internal security:      False
# Python version:             2.7.13 final
# --------------------------  ---------------------------------

# %%
data2 = h2o.H2OFrame(data)
# Out:
# Parse progress: |█████████████████████████████████████████████████████████| 100%

# %%
data2.describe()
# Out:
# Rows:1000
# Cols:22
# <table>
# <thead>
# <tr><th>       </th><th>ca_status  </th><th>duration     </th><th>credit_history  </th><th>purpose            </th><th>credit_amount  </th><th>savings                     </th><th>present_employment_since  </th><th>installment_rate_income  </th><th>status_sex            </th><th>other_debtors  </th><th>present_residence_since  </th><th>property        </th><th>age          </th><th>other_installment  </th><th>housing  </th><th>existing_credits  </th><th>job                    </th><th>liable_maintenance_people  </th><th>telephone  </th><th>foreign_worker  </th><th>gb  </th><th>tar          </th></tr>
# </thead>
# <tbody>
# <tr><td>type   </td><td>enum       </td><td>int          </td><td>enum            </td><td>enum               </td><td>int            </td><td>enum                        </td><td>enum                      </td><td>int                      </td><td>enum                  </td><td>enum           </td><td>int                      </td><td>enum            </td><td>int          </td><td>enum               </td><td>enum     </td><td>int               </td><td>enum                   </td><td>int                        </td><td>enum       </td><td>enum            </td><td>enum</td><td>int          </td></tr>
# <tr><td>mins   </td><td>           </td><td>4.0          </td><td>                </td><td>                   </td><td>250.0          </td><td>                            </td><td>                          </td><td>1.0                      </td><td>                      </td><td>               </td><td>1.0                      </td><td>                </td><td>19.0         </td><td>                   </td><td>         </td><td>1.0               </td><td>                       </td><td>1.0                        </td><td>           </td><td>                </td><td>    </td><td>0.0          </td></tr>
# <tr><td>mean   </td><td>           </td><td>20.903       </td><td>                </td><td>                   </td><td>3271.258       </td><td>                            </td><td>                          </td><td>2.973                    </td><td>                      </td><td>               </td><td>2.845                    </td><td>                </td><td>35.546       </td><td>                   </td><td>         </td><td>1.407             </td><td>                       </td><td>1.155                      </td><td>           </td><td>                </td><td>    </td><td>0.7          </td></tr>
# <tr><td>maxs   </td><td>           </td><td>72.0         </td><td>                </td><td>                   </td><td>18424.0        </td><td>                            </td><td>                          </td><td>4.0                      </td><td>                      </td><td>               </td><td>4.0                      </td><td>                </td><td>75.0         </td><td>                   </td><td>         </td><td>4.0               </td><td>                       </td><td>2.0                        </td><td>           </td><td>                </td><td>    </td><td>1.0          </td></tr>
# <tr><td>sigma  </td><td>           </td><td>12.0588144528</td><td>                </td><td>                   </td><td>2822.73687596  </td><td>                            </td><td>                          </td><td>1.11871467431            </td><td>                      </td><td>               </td><td>1.10371789566            </td><td>                </td><td>11.3754685743</td><td>                   </td><td>         </td><td>0.577654468246    </td><td>                       </td><td>0.362085771753             </td><td>           </td><td>                </td><td>    </td><td>0.45848687027</td></tr>
# <tr><td>zeros  </td><td>           </td><td>0            </td><td>                </td><td>                   </td><td>0              </td><td>                            </td><td>                          </td><td>0                        </td><td>                      </td><td>               </td><td>0                        </td><td>                </td><td>0            </td><td>                   </td><td>         </td><td>0                 </td><td>                       </td><td>0                          </td><td>           </td><td>                </td><td>    </td><td>300          </td></tr>
# <tr><td>missing</td><td>0          </td><td>0            </td><td>0               </td><td>0                  </td><td>0              </td><td>0                           </td><td>0                         </td><td>0                        </td><td>0                     </td><td>0              </td><td>0                        </td><td>0               </td><td>0            </td><td>0                  </td><td>0        </td><td>0                 </td><td>0                      </td><td>0                          </td><td>0          </td><td>0               </td><td>0   </td><td>0            </td></tr>
# <tr><td>0      </td><td>(;0DM)     </td><td>6.0          </td><td>critical        </td><td>radio/television   </td><td>1169.0         </td><td>unknown / no savings account</td><td><7;)                      </td><td>4.0                      </td><td>male:single           </td><td>none           </td><td>4.0                      </td><td>real estate     </td><td>67.0         </td><td>none               </td><td>own      </td><td>2.0               </td><td>skilled/off.           </td><td>1.0                        </td><td>yes        </td><td>yes             </td><td>good</td><td>1.0          </td></tr>
# <tr><td>1      </td><td><0DM;200DM)</td><td>48.0         </td><td>all paid        </td><td>radio/television   </td><td>5951.0         </td><td>(;100DM)                    </td><td><1;4)                     </td><td>2.0                      </td><td>female:div./sep./marr.</td><td>none           </td><td>2.0                      </td><td>real estate     </td><td>22.0         </td><td>none               </td><td>own      </td><td>1.0               </td><td>skilled/off.           </td><td>1.0                        </td><td>none       </td><td>yes             </td><td>bad </td><td>0.0          </td></tr>
# <tr><td>2      </td><td>No Acc.    </td><td>12.0         </td><td>critical        </td><td>education          </td><td>2096.0         </td><td>(;100DM)                    </td><td><4;7)                     </td><td>2.0                      </td><td>male:single           </td><td>none           </td><td>3.0                      </td><td>real estate     </td><td>49.0         </td><td>none               </td><td>own      </td><td>1.0               </td><td>unsk. res.             </td><td>2.0                        </td><td>none       </td><td>yes             </td><td>good</td><td>1.0          </td></tr>
# <tr><td>3      </td><td>(;0DM)     </td><td>42.0         </td><td>all paid        </td><td>furniture/equipment</td><td>7882.0         </td><td>(;100DM)                    </td><td><4;7)                     </td><td>2.0                      </td><td>male:single           </td><td>guarantor      </td><td>4.0                      </td><td>svngs. agrrement</td><td>45.0         </td><td>none               </td><td>for free </td><td>1.0               </td><td>skilled/off.           </td><td>2.0                        </td><td>none       </td><td>yes             </td><td>good</td><td>1.0          </td></tr>
# <tr><td>4      </td><td>(;0DM)     </td><td>24.0         </td><td>delay           </td><td>car (new)          </td><td>4870.0         </td><td>(;100DM)                    </td><td><1;4)                     </td><td>3.0                      </td><td>male:single           </td><td>none           </td><td>4.0                      </td><td>unknown/no      </td><td>53.0         </td><td>none               </td><td>for free </td><td>2.0               </td><td>skilled/off.           </td><td>2.0                        </td><td>none       </td><td>yes             </td><td>bad </td><td>0.0          </td></tr>
# <tr><td>5      </td><td>No Acc.    </td><td>36.0         </td><

# %%
rf_v1 = H2ORandomForestEstimator(
    model_id="Random_forest_FI",
    ntrees=400,
    stopping_rounds=2,
    score_each_iteration=True,
    seed=1000000)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-136-e45fc0eecf10> in <module>()
# ----> 1 rf_v1 = H2ORandomForestEstimator(param)
#
# TypeError: __init__() takes exactly 1 argument (2 given)

# %%
cols_to_use =list(set(data.columns)- set(["tar"]))
start = time.time()
rf_v1.train(cols_to_use,y= "tar", training_frame=data2)
#model_chk_r2.fit(data[cols_to_use], data.tar)
print ('Time taken: ', time.time() - start)
#rf_v1.train(covtype_X, covtype_y, training_frame=train, validation_frame=valid)
# Out:
# drf Model Build progress: |███████████████████████████████████████████████| 100%
# ('Time taken: ', 0.4937901496887207)

# %%
rf_v1
# Out:
# Model Details
# =============
# H2ORandomForestEstimator :  Distributed Random Forest
# Model Key:  Random_forest_FI
#
#
# ModelMetricsRegression: drf
# ** Reported on train data. **
#
# MSE: 0.00321748398688
# RMSE: 0.0567228700515
# MAE: 0.0138320860543
# RMSLE: 0.0403112388629
# Mean Residual Deviance: 0.00321748398688
# Scoring History:
#     timestamp            duration    number_of_trees    training_rmse    training_mae    training_deviance
# --  -------------------  ----------  -----------------  ---------------  --------------  -------------------
#     2017-08-08 15:44:03  0.001 sec   0                  nan              nan             nan
#     2017-08-08 15:44:04  0.247 sec   1                  0.148659         0.0220994       0.0220994
#     2017-08-08 15:44:04  0.276 sec   2                  0.13708          0.0212418       0.0187908
#     2017-08-08 15:44:04  0.288 sec   3                  0.109013         0.0147903       0.0118837
#     2017-08-08 15:44:04  0.299 sec   4                  0.0861296        0.0119608       0.0074183
#     2017-08-08 15:44:04  0.308 sec   5                  0.0974126        0.0172921       0.00948921
#     2017-08-08 15:44:04  0.312 sec   6                  0.0815282        0.0139688       0.00664685
#     2017-08-08 15:44:04  0.316 sec   7                  0.0708558        0.0120312       0.00502054
#     2017-08-08 15:44:04  0.324 sec   8                  0.065689         0.0109922       0.00431504
#     2017-08-08 15:44:04  0.331 sec   9                  0.0680241        0.0125909       0.00462727
#     2017-08-08 15:44:04  0.336 sec   10                 0.0648797        0.0117946       0.00420937
#     2017-08-08 15:44:04  0.341 sec   11                 0.0617004        0.0110307       0.00380693
#     2017-08-08 15:44:04  0.347 sec   12                 0.0561448        0.0111528       0.00315223
#     2017-08-08 15:44:04  0.356 sec   13                 0.0616876        0.0148736       0.00380537
#     2017-08-08 15:44:04  0.360 sec   14                 0.0567229        0.0138321       0.00321748
# Variable Importances:
# variable                   relative_importance    scaled_importance    percentage
# -------------------------  ---------------------  -------------------  -----------------
# gb                         1861.54077148          1.0                  0.829144266496
# ca_status                  188.564743042          0.101294984204       0.0839881553772
# duration                   31.7272720337          0.0170435547369      0.0141315656908
# savings                    31.174118042           0.0167464062671      0.0138851867407
# credit_amount              22.4073524475          0.0120369925767      0.00998040338079
# ---                        ---                    ---                  ---
# existing_credits           2.30148005486          0.00123633072673     0.00102509653356
# housing                    1.92513942719          0.00103416452472     0.000857471586283
# liable_maintenance_people  1.04504621029          0.000561387763458    0.000465471445352
# telephone                  0.2547108531           0.00013682797444     0.000113450130503
# foreign_worker             0.0                    0.0                  0.0
# See the whole table with table.as_data_frame()

# %%
Variable_importance = rf_v1._model_json['output']['variable_importances'].as_data_frame()
# Out:
# Model Summary:
#     number_of_trees    number_of_internal_trees    model_size_in_bytes    min_depth    max_depth    mean_depth    min_leaves    max_leaves    mean_leaves
# --  -----------------  --------------------------  ---------------------  -----------  -----------  ------------  ------------  ------------  -------------
#     14                 14                          12707                  1            11           6             2             39            17.2857
# Scoring History:
#     timestamp            duration    number_of_trees    training_rmse    training_mae    training_deviance
# --  -------------------  ----------  -----------------  ---------------  --------------  -------------------
#     2017-08-08 15:44:03  0.001 sec   0                  nan              nan             nan
#     2017-08-08 15:44:04  0.247 sec   1                  0.148659         0.0220994       0.0220994
#     2017-08-08 15:44:04  0.276 sec   2                  0.13708          0.0212418       0.0187908
#     2017-08-08 15:44:04  0.288 sec   3                  0.109013         0.0147903       0.0118837
#     2017-08-08 15:44:04  0.299 sec   4                  0.0861296        0.0119608       0.0074183
#     2017-08-08 15:44:04  0.308 sec   5                  0.0974126        0.0172921       0.00948921
#     2017-08-08 15:44:04  0.312 sec   6                  0.0815282        0.0139688       0.00664685
#     2017-08-08 15:44:04  0.316 sec   7                  0.0708558        0.0120312       0.00502054
#     2017-08-08 15:44:04  0.324 sec   8                  0.065689         0.0109922       0.00431504
#     2017-08-08 15:44:04  0.331 sec   9                  0.0680241        0.0125909       0.00462727
#     2017-08-08 15:44:04  0.336 sec   10                 0.0648797        0.0117946       0.00420937
#     2017-08-08 15:44:04  0.341 sec   11                 0.0617004        0.0110307       0.00380693
#     2017-08-08 15:44:04  0.347 sec   12                 0.0561448        0.0111528       0.00315223
#     2017-08-08 15:44:04  0.356 sec   13                 0.0616876        0.0148736       0.00380537
#     2017-08-08 15:44:04  0.360 sec   14                 0.0567229        0.0138321       0.00321748
# ModelMetricsRegression: drf
# ** Reported on train data. **
#
# MSE: 0.00321748398688
# RMSE: 0.0567228700515
# MAE: 0.0138320860543
# RMSLE: 0.0403112388629
# Mean Residual Deviance: 0.00321748398688
# Variable Importances:
# variable                   relative_importance    scaled_importance    percentage
# -------------------------  ---------------------  -------------------  -----------------
# gb                         1861.54077148          1.0                  0.829144266496
# ca_status                  188.564743042          0.101294984204       0.0839881553772
# duration                   31.7272720337          0.0170435547369      0.0141315656908
# savings                    31.174118042           0.0167464062671      0.0138851867407
# credit_amount              22.4073524475          0.0120369925767      0.00998040338079
# ---                        ---                    ---                  ---
# existing_credits           2.30148005486          0.00123633072673     0.00102509653356
# housing                    1.92513942719          0.00103416452472     0.000857471586283
# liable_maintenance_people  1.04504621029          0.000561387763458    0.000465471445352
# telephone                  0.2547108531           0.00013682797444     0.000113450130503
# foreign_worker             0.0                    0.0                  0.0
# See the whole table with table.as_data_frame()
# {u'__meta': {u'schema_name': u'DRFModelOutputV3',
#   u'schema_type': u'DRFOutput',
#   u'schema_version': 3},
#  u'cross_validation_fold_assignment_frame_id': None,
#  u'cross_validation_holdout_predictions_frame_id': None,
#  u'cross_validation_metrics': None,
#  u'cross_validation_metrics_summary': None,
#  u'cross_validation_models': None,
#  u'cross_validation_predictions': None,
#  u'domains': [[u'(;0DM)', u'<0DM;200DM)', u'<200DM;)', u'No Acc.'],
#   None,
#   [u'all paid', u'critical', u'delay', u'no credits', u'paid off'],
#   [u'business',
#    u'car (new)',
#    u'car (used)',
#    u'domestic appliances',
#    u'education',
#    u'furniture/equipment',
#    u'others',
#    u'radio/television',
#    u'repairs',
#    u'retraining'],
#   None,
#   [u'(;100DM)',
#    u'<1000;)',
#    u'<100;500)',
#    u'<500;1000)',
#    u'unknown / no savings account'],
#   [u'(;1)', u'<1;4)', u'<4;7)', u'<7;)', u'unemployed'],
#   None,
#   [u'female:div./sep./marr.',
#    u'male:div./sep.',
#    u'male:marr/wid.',
#    u'male:single'],
#   [u'co-applicant', u'guarantor', u'none'],
#   None,
#   [u'car or other', u'real estate', u'svngs. agrrement', u'unknown/no'],
#   None,
#   [u'bank', u'none', u'stores'],
#   [u'for free', u'own', u'rent'],
#   None,
#   [u'mng/self emp, hig qual.',
#    u'skilled/off.',
#    u'unemp./unsk. nonr.',
#    u'unsk. res.'],
#   None,
#   [u'none', u'yes'],
#   [u'no', u'yes'],
#   [u'bad', u'good'],
#   None],
#  u'end_time': 1502187244198,
#  u'help': {u'__meta': u'Metadata on this schema instance, to make it self-describing.',
#   u'cross_validation_fold_assignment_frame_id': u'Cross-validation fold assignment (each row is assigned to one holdout fold)',
#   u'cross_validation_holdout_predictions_frame_id': u'Cross-validation holdout predictions (full out-of-sample predictions on training data)',
#   u'cross_validation_metrics': u'Cross-validation model metrics',
#   u'cross_validation_metrics_summary': u'Cross-validation model metrics summary',
#   u'cross_validation_models': u'Cross-validation models (model ids)',
#   u'cross_validation_predictions': u'Cross-validation predictions, one per cv model (deprecated, use cross_validation_holdout_predictions_frame_id instead)',
#   u'domains': u'Domains for categorical columns',
#   u'end_time': u'End time in milliseconds',
#   u'help': u'Help information for output fields',
#   u'init_f': u'The Intercept term, the initial model function value to which trees make adjustments',
#   u'model_category': u'Category of the model (e.g., Binomial)',
#   u'model_summary': u'Model summary',
#   u'names': u'Column names',
#   u'run_time': u'Runtime in milliseconds',
#   u'scoring_history': u'Scoring history',
#   u'start_time': u'Start time in milliseconds',
#   u'status': u'Job status',
#   u'training_metrics': u'Training data model metrics',
#   u'validation_metrics': u'Validation data model metrics',
#   u'variable_importances': u'Variable Importances'},
#  u'init_f': 0.0,
#  u'model_category': u'Regression',
#  u'model_summary': ,
#  u'names': [u'ca_status',
#   u'duration',
#   u'credit_history',
#   u'purpose',
#   u'credit_amount',
#   u'savings',
#   u'present_employment_since',
#   u'installment_rate_income',
#   u'status_sex',
#   u'other_debtors',
#   u'present_residence_since',
#   u'property',
#   u'age',
#   u'other_installment',
#   u'housing',
#   u'existing_credits',
#   u'job',
#   u'liable_maintenance_people',
#   u'telephone',
#   u'foreign_worker',
#   u'gb',
#   u'tar'],
#  u'run_time': 366,
#  u'scoring_history': ,
#  u'start_time': 1502187243832,
#  u'status': None,
#  u'training_metrics': ,
#  u'validation_metrics': None,
#  u'variable_importances': }
